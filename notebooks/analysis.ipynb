# %%
from IPython.display import IFrame, display

dashboard_url = "http://127.0.0.1:3000/public-dashboards/5d0df81f9c7c41728dc0a59de42ba9f9?orgId=1&kiosk"

display(IFrame(dashboard_url, width="100%", height="1000px"))
# Out:
#         <iframe
#             width="100%"
#             height="1000px"
#             src="http://127.0.0.1:3000/public-dashboards/5d0df81f9c7c41728dc0a59de42ba9f9?orgId=1&kiosk"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
