# %% [markdown]
# # HH Vacancies Analyzer
# Анализ рынка вакансий в Москве: IT vs Курьеры (12 000+ вакансий)
#
# **Дата сбора:** февраль 2026
# **Источник:** публичный API hh.ru
# **Цель:** сравнить ключевые метрики двух профессий (удалёнка, зарплата, опыт, компании, слова в описаниях)
#
# [Репозиторий на GitHub](https://github.com/AlpakaGSB/HH_Vacancies_Dashboard_Analyzer)

# %%
# Импорт библиотек
import pandas as pd
from IPython.display import IFrame, Markdown, display

# %% [markdown]
# ## Живой снапшот дашборда Grafana
#
# [Ссылка на дашборд](https://snapshots.raintank.io/dashboard/snapshot/lKRjPg5Wbpt972npwasPRiPtTcXwCWwv)
# Открывается без авторизации, работает в ноутбуке, на GitHub и в nbviewer.

# %%
from IPython.display import IFrame, display

dashboard_url = "https://snapshots.raintank.io/dashboard/snapshot/lKRjPg5Wbpt972npwasPRiPtTcXwCWwv"

display(IFrame(dashboard_url, width="100%", height="1300px"))
# Out:
#         <iframe
#             width="100%"
#             height="1300px"
#             src="https://snapshots.raintank.io/dashboard/snapshot/lKRjPg5Wbpt972npwasPRiPtTcXwCWwv"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
